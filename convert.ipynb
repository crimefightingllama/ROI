# %% [markdown]
# <a href="https://colab.research.google.com/github/crimefightingllama/ROI/blob/main/convert.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install czifile
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !cp "/content/drive/MyDrive/images/output.tif" "/content" -r

# %%
from czifile import czi2tif
path = "/content/1850.czi"
czi2tif(path, 'output.tif')
# Out:
# Opening CZI file... 0.028032 s
# Image
#   axes:  YX0
#   shape: (27297, 57429, 3)
#   dtype: uint8
#   size:  4.38 GiB
# Creating empty TIF file... 0.003625 s
# Copying image from CZI to TIF file... 3:36.941627 s

# %%
# !cp "/content/output.tif" "/content/drive/MyDrive/images" -r

# %%
from osgeo import gdal

options_list = ['-ot Byte', '-of BMP']
options_string = " ".join(options_list)

gdal.Translate('output.bmp', "/content/drive/MyDrive/images/output.tif", options=options_string)

# %%
import matplotlib.pyplot as plt
from PIL import Image
Image.MAX_IMAGE_PIXELS = 15676394130
img = Image.open("/content/drive/MyDrive/images/output.tif")
# img.save("1850.bmp")
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# <ipython-input-2-f488dbc309b6> in <cell line: 4>()
#       2 from PIL import Image
#       3 Image.MAX_IMAGE_PIXELS = 15676394130
# ----> 4 img = Image.open("/content/drive/MyDrive/images/output.tif")
#       5 # img.save("1850.bmp")
#
# /usr/local/lib/python3.9/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3028     for message in accept_warnings:
#    3029         warnings.warn(message)
# -> 3030     raise UnidentifiedImageError(
#    3031         "cannot identify image file %r" % (filename if filename else fp)
#    3032     )
#
# UnidentifiedImageError: cannot identify image file '/content/drive/MyDrive/images/output.tif'

# %%
from skimage import io
sourcePath = "/content/drive/MyDrive/images/output.tif"
im = io.imread(sourcePath)

# %%
import matplotlib.pyplot as plt
plt.imshow(im)

# %% [markdown]
# START HERE

# %%
# !git clone https://github.com/crimefightingllama/MaskMitosis
# %cd MaskMitosis
# !pip3 install -r requirements.txt
# !python3 setup.py install

# %%
filetoconvert = "/content/drive/MyDrive/images/1850cropped512hd.png"
convertedfile = "1850cropped.bmp"
# !cp "/content/drive/MyDrive/images/1850cropped512hd.png" "/content/MaskMitosis/test/1850cropped/images" -r

# %% [markdown]
# convert to bmp

# %%
rm "/content/MaskMitosis/test/1850cropped/images/1850cropped.bmp"

# %%
from osgeo import gdal
gdal.UseExceptions()
options_list = ['-ot Byte', '-of BMP']
options_string = " ".join(options_list)

gdal.Translate('1850cropped.bmp', "/content/MaskMitosis/test/1850cropped/images/1850cropped512hd.png", options=options_string)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-7-7d6bbcee2151> in <cell line: 6>()
#       4 options_string = " ".join(options_list)
#       5
# ----> 6 gdal.Translate('1850cropped.bmp', "/content/MaskMitosis/test/1850cropped/images/1850cropped512hd.png", options=options_string)
#
# /usr/local/lib/python3.9/dist-packages/osgeo/gdal.py in Translate(destName, srcDS, **kwargs)
#     482         srcDS = Open(srcDS)
#     483
# --> 484     return TranslateInternal(destName, srcDS, opts, callback, callback_data)
#     485
#     486 def WarpOptions(options=None, format=None,
#
# /usr/local/lib/python3.9/dist-packages/osgeo/gdal.py in TranslateInternal(*args)
#    4569 def TranslateInternal(*args):
# ...

# %%
# !pip install image_slicer
# import image_slicer
# image_slicer.slice('/content/MaskMitosis/test/1850/images/1850.bmp', 14)

# %%
# !cp "/content/MaskMitosis/test/1850/images" "/content/drive/MyDrive/images" -r

# %%
# !cp "/content/MaskMitosis/test/1850/images/1850.bmp" "/content/drive/MyDrive/images" -r

# %%
# from osgeo import gdal

# options_list = ['-ot Byte', '-of BMP']
# options_string = " ".join(options_list)

# gdal.Translate('1850.bmp', "/content/MaskMitosis/test/1850/images/1850_02_01.png", options=options_string)
# Out:
# <osgeo.gdal.Dataset; proxy of <Swig Object of type 'GDALDatasetShadow *' at 0x7f6b33fe0f90> >

# %% [markdown]
# ## Detect

# %%
# print(PIL.__file__)
# Out:
# /usr/local/lib/python3.9/dist-packages/PIL/__init__.py

# %%
# !cd /usr/local/lib/python3.9/dist-packages/PIL
# !grep -r -A 2 'exceeds limit' .

# %%
# !grep -r MAX_IMAGE_PIXELS
# Out:
# MaskMitosis14_detection/Measure_detection_2014.py:Image.MAX_IMAGE_PIXELS = None

# %%
rmdir /content/MaskMitosis/test/.ipynb_checkpoints

# %%
from PIL import Image
Image.MAX_IMAGE_PIXELS = 43674816990
import PIL
PIL.Image.MAX_IMAGE_PIXELS = 43674816990
# !cp "/content/drive/MyDrive/weights/mitosis2012_weights.h5" "/content/MaskMitosis"  -r
# !python ./MaskMitosis12_detection/mitosis.py detect --dataset="/content/MaskMitosis" --subset=test --weights="/content/MaskMitosis/mitosis2012_weights.h5"
# Out:
# 2023-04-14 16:48:57.746548: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-14 16:48:58.655004: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.9/dist-packages/mask_rcnn-2.1-py3.9.egg/mrcnn/model.py:2337: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /usr/local/lib/python3.9/dist-packages/mask_rcnn-2.1-py3.9.egg/mrcnn/model.py:2337: SyntaxWarning: "is" with a literal. Did you mean "=="?
# Weights:  /content/MaskMitosis/mitosis2012_weights.h5
# Dataset:  /content/MaskMitosis
# Subset:  test
# Logs:  /content/MaskMitosis12_detection/logs
#
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# ...

# %%
# !python ./MaskMitosis12_detection/mitosis.py detect --dataset="/content/MaskMitosis" --subset=test --weights="/content/MaskMitosis/mitosis2012_weights.h5"
# Out:
# 2023-04-13 14:13:07.476889: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-13 14:13:08.372796: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.9/dist-packages/mask_rcnn-2.1-py3.9.egg/mrcnn/model.py:2337: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /usr/local/lib/python3.9/dist-packages/mask_rcnn-2.1-py3.9.egg/mrcnn/model.py:2337: SyntaxWarning: "is" with a literal. Did you mean "=="?
# Weights:  /content/MaskMitosis/mitosis2012_weights.h5
# Dataset:  /content/MaskMitosis
# Subset:  test
# Logs:  /content/MaskMitosis12_detection/logs
#
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# ...

# %%
# !python ./MaskMitosis12_detection/mitosis.py detect --dataset="/content/MaskMitosis" --subset=test --weights="/content/MaskMitosis/mitosis2012_weights.h5"
# Out:
# 2023-04-13 14:08:27.905446: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-13 14:08:28.838381: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.9/dist-packages/mask_rcnn-2.1-py3.9.egg/mrcnn/model.py:2337: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /usr/local/lib/python3.9/dist-packages/mask_rcnn-2.1-py3.9.egg/mrcnn/model.py:2337: SyntaxWarning: "is" with a literal. Did you mean "=="?
# Weights:  /content/MaskMitosis/mitosis2012_weights.h5
# Dataset:  /content/MaskMitosis
# Subset:  test
# Logs:  /content/MaskMitosis12_detection/logs
#
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# ...

# %%
# !python ./MaskMitosis12_detection/mitosis.py detect --dataset="/content/MaskMitosis" --subset=test --weights="/content/MaskMitosis/mitosis2012_weights.h5"
# Out:
# 2023-04-13 14:08:27.905446: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-13 14:08:28.838381: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.9/dist-packages/mask_rcnn-2.1-py3.9.egg/mrcnn/model.py:2337: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /usr/local/lib/python3.9/dist-packages/mask_rcnn-2.1-py3.9.egg/mrcnn/model.py:2337: SyntaxWarning: "is" with a literal. Did you mean "=="?
# Weights:  /content/MaskMitosis/mitosis2012_weights.h5
# Dataset:  /content/MaskMitosis
# Subset:  test
# Logs:  /content/MaskMitosis12_detection/logs
#
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# ...

# %%
# import czifile
# path = "/content/1850.czi"
# with czifile.CziFile(path) as czi:
#     image = czi.asarray()
#     czifile.imwrite('output.tif', image, bigtiff=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-423323bd35f4> in <cell line: 3>()
#       3 with czifile.CziFile(path) as czi:
#       4     image = czi.asarray()
# ----> 5     czifile.imwrite('output.tif', image, bigtiff=True)
#
# AttributeError: module 'czifile' has no attribute 'imwrite'

# %%
# !pip install slideio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 MB 8.6 MB/s eta 0:00:00
# ...

# %%
import slideio
import matplotlib.pyplot as plt

slide = slideio.open_slide(path, "CZI")
scene = slide.get_scene(0)
plt.imshow(scene.read_block())

# %%
pip install python-bioformats
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.6/40.6 MB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.6/135.6 kB 17.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 60.0 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
bfconvert path output.tiff
# Out:
#   File "<ipython-input-2-ca1bec13b8e9>", line 1
#     bfconvert path output.tiff
#               ^
# SyntaxError: invalid syntax
